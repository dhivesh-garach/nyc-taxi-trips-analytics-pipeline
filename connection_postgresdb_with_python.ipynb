# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
postgres_engine = create_engine('postgresql://root:root@localhost:5431/ny_taxi')
postgres_engine.connect()

# %%
query = '''
select * from yellow_taxi_data
limit 1000;
'''
df = pd.read_sql(query, postgres_engine)
df
# Out:
#      index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0     3840         1  2021-01-01 04:05:37   2021-01-01 04:19:49
# 1     3841         1  2021-01-01 04:44:25   2021-01-01 04:44:46
# 2     3842         2  2021-01-01 04:12:38   2021-01-01 04:28:57
# 3     3843         2  2021-01-01 04:05:26   2021-01-01 04:05:38
# 4     3844         2  2021-01-01 04:05:26   2021-01-01 04:05:38
# ..     ...       ...                  ...                   ...
# 995   4835         2  2021-01-01 08:55:44   2021-01-01 09:07:33
# 996   4836         2  2021-01-01 08:14:35   2021-01-01 08:30:55
# 997   4837         2  2021-01-01 08:18:47   2021-01-01 08:33:26
# 998   4838         1  2021-01-01 08:51:38   2021-01-01 09:07:39
# 999   4839         2  2021-01-01 08:32:28   2021-01-01 08:43:55
#
#      passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                  1           4.30           1                  N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  1000 non-null   int64
#  1   VendorID               1000 non-null   int64
#  2   tpep_pickup_datetime   1000 non-null   object
#  3   tpep_dropoff_datetime  1000 non-null   object
#  4   passenger_count        1000 non-null   int64
#  5   trip_distance          1000 non-null   float64
#  6   RatecodeID             1000 non-null   int64
#  7   store_and_fwd_flag     1000 non-null   object
#  8   PULocationID           1000 non-null   int64
#  9   DOLocationID           1000 non-null   int64
#  10  payment_type           1000 non-null   int64
#  11  fare_amount            1000 non-null   float64
#  12  extra                  1000 non-null   float64
#  13  mta_tax                1000 non-null   float64
# ...
